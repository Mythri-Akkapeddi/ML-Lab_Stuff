# %%
import sympy as sp

# %%
x, y, z = sp.symbols('x y z')

# %%
f1 = x**2 + y*z
f2 = y**2 + x*z
f3 = z**2 + x*y

# %%
vec = sp.Matrix([x, y, z])
func=sp.Matrix([f1, f2, f3])

# %%
Jacobian = func.jacobian(vec)

# %%
print(Jacobian)
# Out:
# Matrix([[2*x, z, y], [z, 2*y, x], [y, x, 2*z]])
